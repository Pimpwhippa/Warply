# %%
import csv
var1 = "userid"
var2 = "last_login"
csv_dic={var1:[], var2:[]}
csvFile = csv.reader(open('/home/pimpwhippa/Works/tornado_todo/todo/User_s_no_binary.csv', encoding ='us-ascii'))
for row in csvFile:
    csv_dic[var1].append(row[0])
    csv_dic[var2].append(row[1])
            #csv_dic[var3].append(row[2])
            #csv_dic[var4].append(row[3])
        #self.write(csv_dic)
print(csv_dic)
# Out:
# {'userid': ['userid', '3652', '3150', '3855', '3700', '5888', '5432', '5198', '8365', '863', '6297', '2252', '8355', '6585', '9261', '7342', '760', '4383', '7085', '5952', '6727', '3350', '5241', '931', '5284', '8021', '318', '1585', '8769', '3025', '7409', '2604', '4635', '5951', '8303', '4071', '3276', '1731', '3496', '7023', '7349', '1726', '1839', '9886', '8616', '203', '8431', '2114', '5438', '980', '8773', '9154', '7474', '8995', '5526', '733', '9151', '1293', '971', '9475', '1070', '7557', '3470', '4517', '2880', '3561', '4528', '361', '3101', '2803', '8270', '5100', '537', '2522', '5077', '2127', '9254', '3679', '9550', '8857', '5963', '5616', '4634', '5782', '7116', '9489', '3985', '5276', '2161', '7968', '4656', '9577', '6392', '6628', '3653', '5087', '9536', '2674', '3466', '3432', '8335', '8375', '682', '8407', '1616', '2345', '4593', '304', '7336', '6280', '9891', '1830', '3325', '306', '5497', '7310', '2581', '9226', '3810', '9639', '1631', '8760', '832', '7272', '2048'
# ...

# %%
pwd
# Out:
# '/home/pimpwhippa/Works/tornado_todo'

# %%
csvFile

# %%
csv_dic
# Out:
# {'userid': ['userid',
#   '3652',
#   '3150',
#   '3855',
#   '3700',
#   '5888',
#   '5432',
#   '5198',
#   '8365',
#   '863',
#   '6297',
#   '2252',
#   '8355',
#   '6585',
#   '9261',
#   '7342',
#   '760',
#   '4383',
#   '7085',
#   '5952',
#   '6727',
#   '3350',
#   '5241',
#   '931',
#   '5284',
#   '8021',
#   '318',
#   '1585',
#   '8769',
#   '3025',
#   '7409',
#   '2604',
#   '4635',
#   '5951',
#   '8303',
#   '4071',
#   '3276',
#   '1731',
#   '3496',
#   '7023',
#   '7349',
#   '1726',
#   '1839',
#   '9886',
#   '8616',
#   '203',
#   '8431',
#   '2114',
#   '5438',
#   '980',
#   '8773',
#   '9154',
#   '7474',
#   '8995',
#   '5526',
#   '733',
#   '9151',
#   '1293',
#   '971',
#   '9475',
#   '1070',
#   '7557',
#   '3470',
#   '4517',
#   '2880',
#   '3561',
#   '4528',
#   '361',
#   '3101',
#   '2803',
#   '8270',
#   '5100',
#   '537',
#   '2522',
#   '5077',
#   '2127',
#   '9254',
#   '3679',
#   '9550',
#   '8857',
#   '5963',
#   '5616',
#   '4634',
# ...

# %%
csv_dic['last_login']
# Out:
# ['last_login',
#  '2020-06-17 10:58:11',
#  '2020-05-17 08:18:33',
#  '2020-06-23 15:22:27',
#  '2020-06-11 21:37:37',
#  '2020-05-30 14:18:06',
#  '2020-05-21 05:36:45',
#  '2020-07-02 15:11:00',
#  '2020-06-09 21:01:03',
#  '2020-05-20 23:25:15',
#  '2020-05-14 12:24:52',
#  '2020-06-16 13:51:16',
#  '2020-06-14 04:37:53',
#  '2020-05-30 13:00:56',
#  '2020-06-06 16:26:55',
#  '2020-06-09 20:49:34',
#  '2020-06-18 04:06:15',
#  '2020-05-11 02:29:28',
#  '2020-05-28 21:14:16',
#  '2020-06-11 14:14:39',
#  '2020-05-18 08:06:14',
#  '2020-06-17 09:15:32',
#  '2020-07-02 09:52:39',
#  '2020-06-02 17:12:26',
#  '2020-06-11 01:20:07',
#  '2020-06-18 20:03:06',
#  '2020-06-17 20:25:19',
#  '2020-06-08 06:44:17',
#  '2020-07-02 06:35:02',
#  '2020-05-20 06:35:28',
#  '2020-05-26 12:57:46',
#  '2020-05-05 06:12:53',
#  '2020-06-10 08:47:16',
#  '2020-05-03 18:29:45',
#  '2020-06-09 22:38:47',
#  '2020-06-27 21:08:16',
#  '2020-05-22 20:03:36',
#  '2020-06-13 07:28:08',
# ...

# %%
import json
last_login = json.dumps(csv_dic['last_login'])
len(last_login)
# Out:
# 11491

# %%
last_login
# Out:
# '["last_login", "2020-06-17 10:58:11", "2020-05-17 08:18:33", "2020-06-23 15:22:27", "2020-06-11 21:37:37", "2020-05-30 14:18:06", "2020-05-21 05:36:45", "2020-07-02 15:11:00", "2020-06-09 21:01:03", "2020-05-20 23:25:15", "2020-05-14 12:24:52", "2020-06-16 13:51:16", "2020-06-14 04:37:53", "2020-05-30 13:00:56", "2020-06-06 16:26:55", "2020-06-09 20:49:34", "2020-06-18 04:06:15", "2020-05-11 02:29:28", "2020-05-28 21:14:16", "2020-06-11 14:14:39", "2020-05-18 08:06:14", "2020-06-17 09:15:32", "2020-07-02 09:52:39", "2020-06-02 17:12:26", "2020-06-11 01:20:07", "2020-06-18 20:03:06", "2020-06-17 20:25:19", "2020-06-08 06:44:17", "2020-07-02 06:35:02", "2020-05-20 06:35:28", "2020-05-26 12:57:46", "2020-05-05 06:12:53", "2020-06-10 08:47:16", "2020-05-03 18:29:45", "2020-06-09 22:38:47", "2020-06-27 21:08:16", "2020-05-22 20:03:36", "2020-06-13 07:28:08", "2020-05-12 14:59:50", "2020-06-11 01:22:02", "2020-06-03 16:24:14", "2020-06-05 17:47:59", "2020-05-31 04:44:58", "2020-06-12 14:5
# ...

# %%
len(csv_dic['last_login'])
# Out:
# 500

# %%
from datetime import datetime
x = []
for i in csv_dic['last_login']:
    x.append(datetime.strptime(last_login, "%Y-%m-%d %H:%M:%S"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ea369f7eddce> in <module>
#       2 x = []
#       3 for i in csv_dic['last_login']:
# ----> 4     x.append(datetime.strptime(last_login, "%Y-%m-%d %H:%M:%S"))
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
# ...

# %%
csv_dic['last_login'].dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-de6266162527> in <module>
# ----> 1 csv_dic['last_login'].dtype
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
import csv
from datetime import datetime

var1 = "userid"
var2 = "last_login"
var3 = "now"
now = datetime.now()
csv_dic={var1:[], var2:[], var3:[]}
csvFile = csv.reader(open('/home/pimpwhippa/Works/tornado_todo/todo/User_s_no_binary.csv', encoding ='us-ascii'))
for row in csvFile:
    csv_dic[var1].append(row[0])
    csv_dic[var2].append(row[1])
    csv_dic[var3].append(now)
            #csv_dic[var4].append(row[3])
        #self.write(csv_dic)
    print(csv_dic)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import csv
from datetime import datetime

var1 = "userid"
var2 = "last_login"
var3 = "since"
since = datetime.now() - csv_dic[var2]
csv_dic={var1:[], var2:[], var3:[]}
csvFile = csv.reader(open('/home/pimpwhippa/Works/tornado_todo/todo/User_s_no_binary.csv', encoding ='us-ascii'))
for row in csvFile:
    csv_dic[var1].append(row[0])
    csv_dic[var2].append(row[1])
    csv_dic[var3].append(since)
            #csv_dic[var4].append(row[3])
        #self.write(csv_dic)
print(csv_dic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9bf1a81d5bd3> in <module>
#       5 var2 = "last_login"
#       6 var3 = "since"
# ----> 7 since = datetime.now() - csv_dic[var2]
#       8 csv_dic={var1:[], var2:[], var3:[]}
#       9 csvFile = csv.reader(open('/home/pimpwhippa/Works/tornado_todo/todo/User_s_no_binary.csv', encoding ='us-ascii'))
#
# TypeError: unsupported operand type(s) for -: 'datetime.datetime' and 'list'

# %%
since = datetime.now()
since
# Out:
# datetime.datetime(2020, 7, 22, 10, 40, 49, 123154)

# %%
csv_dic[var2]
# Out:
# ['last_login',
#  '2020-06-17 10:58:11',
#  '2020-05-17 08:18:33',
#  '2020-06-23 15:22:27',
#  '2020-06-11 21:37:37',
#  '2020-05-30 14:18:06',
#  '2020-05-21 05:36:45',
#  '2020-07-02 15:11:00',
#  '2020-06-09 21:01:03',
#  '2020-05-20 23:25:15',
#  '2020-05-14 12:24:52',
#  '2020-06-16 13:51:16',
#  '2020-06-14 04:37:53',
#  '2020-05-30 13:00:56',
#  '2020-06-06 16:26:55',
#  '2020-06-09 20:49:34',
#  '2020-06-18 04:06:15',
#  '2020-05-11 02:29:28',
#  '2020-05-28 21:14:16',
#  '2020-06-11 14:14:39',
#  '2020-05-18 08:06:14',
#  '2020-06-17 09:15:32',
#  '2020-07-02 09:52:39',
#  '2020-06-02 17:12:26',
#  '2020-06-11 01:20:07',
#  '2020-06-18 20:03:06',
#  '2020-06-17 20:25:19',
#  '2020-06-08 06:44:17',
#  '2020-07-02 06:35:02',
#  '2020-05-20 06:35:28',
#  '2020-05-26 12:57:46',
#  '2020-05-05 06:12:53',
#  '2020-06-10 08:47:16',
#  '2020-05-03 18:29:45',
#  '2020-06-09 22:38:47',
#  '2020-06-27 21:08:16',
#  '2020-05-22 20:03:36',
#  '2020-06-13 07:28:08',
# ...

# %%
a = datetime.now()

# %%
b = datetime.now() - a
b
# Out:
# datetime.timedelta(seconds=25, microseconds=877081)

# %%
datetime.timedelta(0, 6, 793600)
>>> str(b)
'0:00:06.793600'

# %%
str(b)
# Out:
# '0:00:25.877081'

# %%
x = []
for i in range(len(csv_dic[var2])):
    x.append(datetime.strptime(csv_dic[var2][i], "%Y-%m-%d %H:%M:%S"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-9d50703929dd> in <module>
#       1 x = []
#       2 for i in range(len(csv_dic[var2])):
# ----> 3     x.append(datetime.strptime(csv_dic[var2][i], "%Y-%m-%d %H:%M:%S"))
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
# ...

# %%
for i in csv_dic[var2]:
    datetime.strptime(i,'%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-25fc2eef5b4c> in <module>
#       1 for i in csv_dic[var2]:
# ----> 2     datetime.strptime(i,'%Y-%m-%d %H:%M:%S')
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
# ...

# %%
var2:[]

# %%
import csv
from datetime import datetime

#var2 = 'last_login'
since = datetime.now()
csv_dic=[]
csvFile = csv.reader(open('/home/pimpwhippa/Works/tornado_todo/todo/User_s_no_binary.csv', encoding ='us-ascii'))
for row in csvFile:
    csv_dic.append(row[1])
    csv_dic.append(since)
    #csv_dic[var3].append(since)
            #csv_dic[var4].append(row[3])
        #self.write(csv_dic)
print(csv_dic)
# Out:
# ['last_login', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-06-17 10:58:11', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-05-17 08:18:33', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-06-23 15:22:27', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-06-11 21:37:37', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-05-30 14:18:06', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-05-21 05:36:45', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-07-02 15:11:00', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-06-09 21:01:03', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-05-20 23:25:15', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-05-14 12:24:52', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-06-16 13:51:16', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-06-14 04:37:53', datetime.datetime(2020, 7, 22, 12, 59, 35, 987544), '2020-05-30 13:00:56', datetime
# ...

# %%
csv_dic[0]
# Out:
# 'last_login'

# %%
csv_dic[1]
# Out:
# datetime.datetime(2020, 7, 22, 12, 59, 35, 987544)

# %%
csv_dic[2]
# Out:
# '2020-06-17 10:58:11'

# %%
csv_dic[3]
# Out:
# datetime.datetime(2020, 7, 22, 12, 59, 35, 987544)

# %%
csv_dic[4]
# Out:
# '2020-05-17 08:18:33'

# %%
start from csv_dic[1]
csv_dic[1+1]

# %%
then, you can append all your datetime objects. Or even more Pythonian:

x = [datetime.strptime(s, "%Y-%m-%d %H:%M:%S") for s in date_str]

# %%
import csv
from datetime import datetime

since = datetime.now()
csv_dic=[]
csvFile = csv.reader(open('/home/pimpwhippa/Documents/Works/tornado/last_login.csv', encoding ='us-ascii'))
for col in csvFile:
    csv_dic.append(col[0])
    csv_dic.append(since)
    #csv_dic[var3].append(since)
            #csv_dic[var4].append(row[3])
        #self.write(csv_dic)
print(csv_dic)
# Out:
# ['2020-06-17 10:58:11', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-05-17 08:18:33', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-06-23 15:22:27', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-06-11 21:37:37', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-05-30 14:18:06', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-05-21 05:36:45', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-07-02 15:11:00', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-06-09 21:01:03', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-05-20 23:25:15', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-05-14 12:24:52', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-06-16 13:51:16', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-06-14 04:37:53', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-05-30 13:00:56', datetime.datetime(2020, 7, 25, 13, 8, 58, 763116), '2020-06-06 16:26:55', datetime.dat
# ...

# %%
csv_dic[0]
# Out:
# '2020-06-17 10:58:11'

# %%
csv_dic[1]
# Out:
# datetime.datetime(2020, 7, 23, 10, 29, 56, 419580)

# %%
csv_dic[40]
# Out:
# '2020-06-17 09:15:32'

# %%
x = []
for i in range(len(csv_dic[0])):
    x.append(datetime.strptime(csv_dic[0][i], "%Y-%m-%d %H:%M:%S"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-f49b4fb5cb59> in <module>
#       1 x = []
#       2 for i in range(len(csv_dic[0])):
# ----> 3     x.append(datetime.strptime(csv_dic[0][i], "%Y-%m-%d %H:%M:%S"))
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
# ...

# %%
csv_dic
# Out:
# ['2020-06-17 10:58:11',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-05-17 08:18:33',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-06-23 15:22:27',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-06-11 21:37:37',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-05-30 14:18:06',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-05-21 05:36:45',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-07-02 15:11:00',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-06-09 21:01:03',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-05-20 23:25:15',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-05-14 12:24:52',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-06-16 13:51:16',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-06-14 04:37:53',
#  datetime.datetime(2020, 7, 24, 0, 48, 19, 480154),
#  '2020-05-30 13:00:56',
# ...

# %%
len(csv_dic[0])
# Out:
# 19

# %%
csv_dic[1] - csv_dic[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-caddd4229c15> in <module>
# ----> 1 csv_dic[1] - csv_dic[0]
#
# TypeError: unsupported operand type(s) for -: 'datetime.datetime' and 'str'

# %%
csv_dic[0]
# Out:
# '2020-06-17 10:58:11'

# %%
datetime.strptime((csv_dic[0]), "%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2020, 6, 17, 10, 58, 11)

# %%
x= []
for row in csv_dic[:7]:
    x.append(datetime.strptime(csv_dic[7], "%Y-%m-%d %H:%M:%S"))
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1f308c5e2942> in <module>
#       1 x= []
#       2 for row in csv_dic[:7]:
# ----> 3     x.append(datetime.strptime(csv_dic[7], "%Y-%m-%d %H:%M:%S"))
#       4 x
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
datetime.strptime(csv_dic[6:20], "%Y-%m-%d %H:%M:%S")
csv_dic[6:20]
TypeError: strptime() argument 1 must be str, not list
    
x.append(datetime.strptime(csv_dic[i], "%Y-%m-%d %H:%M:%S"))
i
TypeError: list indices must be integers or slices, not str
    
x.append(datetime.strptime(csv_dic[6], "%Y-%m-%d %H:%M:%S"))
no error

# %%
i
# Out:
# '2020-06-17 10:58:11'

# %%
for row in csv_dic[:7]:
    print(row)
    #datetime.strptime(csv_dic[3:5], "%Y-%m-%d %H:%M:%S")
# Out:
# 2020-06-17 10:58:11
# 2020-07-23 10:29:56.419580
# 2020-05-17 08:18:33
# 2020-07-23 10:29:56.419580
# 2020-06-23 15:22:27
# 2020-07-23 10:29:56.419580
# 2020-06-11 21:37:37

# %%
import pandas as pd
df = pd.read_csv('/home/pimpwhippa/Documents/Works/tornado/last_login.csv', encoding ='us-ascii', header =0, parse_dates =[0])

df.rename(columns={"2020-06-17 10:58:11": "last_login"})
df['now'] = datetime.now()
df['since'] = df['now']-df['2020-06-17 10:58:11']
df
# Out:
#    2020-06-17 10:58:11                        now                   since
# 0  2020-05-17 08:18:33 2020-07-25 13:09:06.164554 69 days 04:50:33.164554
# 1  2020-06-23 15:22:27 2020-07-25 13:09:06.164554 31 days 21:46:39.164554
# 2  2020-06-11 21:37:37 2020-07-25 13:09:06.164554 43 days 15:31:29.164554
# 3  2020-05-30 14:18:06 2020-07-25 13:09:06.164554 55 days 22:51:00.164554
# 4  2020-05-21 05:36:45 2020-07-25 13:09:06.164554 65 days 07:32:21.164554
# 5  2020-07-02 15:11:00 2020-07-25 13:09:06.164554 22 days 21:58:06.164554
# 6  2020-06-09 21:01:03 2020-07-25 13:09:06.164554 45 days 16:08:03.164554
# 7  2020-05-20 23:25:15 2020-07-25 13:09:06.164554 65 days 13:43:51.164554
# 8  2020-05-14 12:24:52 2020-07-25 13:09:06.164554 72 days 00:44:14.164554
# 9  2020-06-16 13:51:16 2020-07-25 13:09:06.164554 38 days 23:17:50.164554
# 10 2020-06-14 04:37:53 2020-07-25 13:09:06.164554 41 days 08:31:13.164554
# 11 2020-05-30 13:00:56 2020-07-25 13:09:06.164554 56 days 00:08:10.164554
# ...

# %%
import csv
from datetime import datetime
import json

#now = datetime.now()
csv_dic=[]
csvFile = csv.reader(open('/home/pimpwhippa/Documents/Works/tornado/last_login.csv'))
for col in csvFile:
    csv_dic.append(col[0]) #or append(col) with returns a list of list
    #ในที่สุดก็รู้แล้วว่าจะทำ list or dict ให้เป็น str ก็แค่ json.dumps(dict)
    #TypeError: strptime() argument 1 must be str, not datetime.datetime
    #csv_dic = json.dumps(csv_dic)
    #csv_dic.append(now)
    #csv_dic = datetime.strptime(csv_dic, "%Y-%m-%d %H:%M:%S")
#now - (datetime.strptime(csv_dic, "%Y-%m-%d %H:%M:%S"))
print(csv_dic)
# Out:
# ['2020-06-17 10:58:11', '2020-05-17 08:18:33', '2020-06-23 15:22:27', '2020-06-11 21:37:37', '2020-05-30 14:18:06', '2020-05-21 05:36:45', '2020-07-02 15:11:00', '2020-06-09 21:01:03', '2020-05-20 23:25:15', '2020-05-14 12:24:52', '2020-06-16 13:51:16', '2020-06-14 04:37:53', '2020-05-30 13:00:56', '2020-06-06 16:26:55', '2020-06-09 20:49:34', '2020-06-18 04:06:15', '2020-05-11 02:29:28', '2020-05-28 21:14:16', '2020-06-11 14:14:39', '2020-05-18 08:06:14', '2020-06-17 09:15:32', '2020-07-02 09:52:39', '2020-06-02 17:12:26', '2020-06-11 01:20:07']

# %%
csvFile

# %%
full_str = ' '.join([str(elem) for elem in list_of_num])

string.join(csvFile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-173-948bd23af100> in <module>
# ----> 1 string.join(csvFile)
#
# NameError: name 'string' is not defined

# %%
str(csv_dic)
# Out:
# "['2020-06-17 10:58:11', '2020-05-17 08:18:33', '2020-06-23 15:22:27', '2020-06-11 21:37:37', '2020-05-30 14:18:06', '2020-05-21 05:36:45', '2020-07-02 15:11:00', '2020-06-09 21:01:03', '2020-05-20 23:25:15', '2020-05-14 12:24:52', '2020-06-16 13:51:16', '2020-06-14 04:37:53', '2020-05-30 13:00:56', '2020-06-06 16:26:55', '2020-06-09 20:49:34', '2020-06-18 04:06:15', '2020-05-11 02:29:28', '2020-05-28 21:14:16', '2020-06-11 14:14:39', '2020-05-18 08:06:14', '2020-06-17 09:15:32', '2020-07-02 09:52:39', '2020-06-02 17:12:26', '2020-06-11 01:20:07']"

# %%
from datetime import datetime

mytime = "2015-02-16 10:36:41.387000"
myTime = datetime.strptime(mytime, "%Y-%m-%d %H:%M:%S.%f")

myFormat = "%Y-%m-%d %H:%M:%S"

print ("Original", myTime)
print ("New", myTime.strftime(myFormat))
# Out:
# Original 2015-02-16 10:36:41.387000
# New 2015-02-16 10:36:41

# %%
now = datetime.now()
with open('/home/pimpwhippa/Documents/Works/tornado/last_login.csv', 'r', encoding ='us-ascii') as f:
    dic = []
    x =[]
    count = 0
    for line in f:
        x.append(datetime.strptime(line, "%Y-%m-%d %H:%M:%S"))

        #dic.append(now)
        #count+=1
        #if count % 2 == 0: #this is the remainder operator
        print(line)
    #print(dic)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-040f6235c99b> in <module>
#       5     count = 0
#       6     for line in f:
# ----> 7         x.append(datetime.strptime(line, "%Y-%m-%d %H:%M:%S"))
#       8
#       9         #dic.append(now)
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /snap/jupyter/6/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     360     if len(data_string) != found.end():
#     361         raise ValueError("unconverted data remains: %s" %
# --> 362                           data_string[found.end():])
# ...

# %%
#for k, v in lastlogin:
        #TypeError: 'int' object is not iterable

        #only want value from the key:value pair
        #ValueError: time data '0' does not match format '%Y-%m-%d %H:%M:%S'
        #for login in lastlogin:
        #    csvFile['last_logindate'] = datetime.strptime(str(login), "%Y-%m-%d %H:%M:%S")

        #csvFile['since'] = csvFile['last_logindate'] - now

# %%
import time 
import datetime 
  
  
string = "20/01/2020"
print(time.mktime(datetime.datetime.strptime(string, "%d/%m/%Y").timetuple()))
# Out:
# 1579474800.0

# %%
import pandas as pd
csvFile = pd.read_csv('/home/pimpwhippa/Works/tornado_todo/todo/User_s_no_binary.csv', index_col = None, parse_dates = [0])
#csvFile.to_dict()
csvFile
# Out:
#     userid           last_login
# 0     3652  2020-06-17 10:58:11
# 1     3150  2020-05-17 08:18:33
# 2     3855  2020-06-23 15:22:27
# 3     3700  2020-06-11 21:37:37
# 4     5888  2020-05-30 14:18:06
# ..     ...                  ...
# 494    559  2020-06-04 15:12:42
# 495   6732  2020-05-02 18:29:26
# 496   9938  2020-05-28 08:06:16
# 497   9949  2020-06-19 06:19:33
# 498   8521  2020-05-02 21:11:11
#
# [499 rows x 2 columns]

# %%
lastlogin = (csvFile['last_login']).items()
lastlogin

# %%
#new_dict = {}
def blabla():
    for k, v in lastlogin:
        bla = datetime.strptime(v, "%Y-%m-%d %H:%M:%S")
    #new_dict[datetime.strptime(v, "%Y-%m-%d %H:%M:%S")] = v
    return bla
print(blabla)
# Out:
# <function blabla at 0x7ff1f2b17510>

# %%
##this works!

csvFile = pd.read_csv('/home/pimpwhippa/Works/tornado_todo/todo/User_s_no_binary.csv', parse_dates = ['last_login'])
#csvFile = csvFile.to_dict()
#for k, v in csvFile['last_login'].items():
    #print(k,v)
    #for v in (k,v):
        #bla = datetime.strptime(v, "%Y-%m-%d %H:%M:%S")
#value = str(csvFile['last_login'].values())
#value
#bla = datetime.strptime(value, "%Y-%m-%d %H:%M:%S")
#bla

# %%
csvFile
# Out:
#      userid          last_login
# 0      3652 2020-06-17 10:58:11
# 1      3150 2020-05-17 08:18:33
# 2      3855 2020-06-23 15:22:27
# 3      3700 2020-06-11 21:37:37
# 4      5888 2020-05-30 14:18:06
# ..      ...                 ...
# 494     559 2020-06-04 15:12:42
# 495    6732 2020-05-02 18:29:26
# 496    9938 2020-05-28 08:06:16
# 497    9949 2020-06-19 06:19:33
# 498    8521 2020-05-02 21:11:11
#
# [499 rows x 2 columns]

# %%
#datetime.strptime(csvFile['last_login'],"%Y-%m-%d %H:%M:%S")
##this works..finally!
now = datetime.now()
csvFile['now'] = now
csvFile['since'] = csvFile['now'] - csvFile['last_login']
csvFile['since']
# Out:
# 0     38 days 03:16:39.825195
# 1     69 days 05:56:17.825195
# 2     31 days 22:52:23.825195
# 3     43 days 16:37:13.825195
# 4     55 days 23:56:44.825195
#                 ...
# 494   50 days 23:02:08.825195
# 495   83 days 19:45:24.825195
# 496   58 days 06:08:34.825195
# 497   36 days 07:55:17.825195
# 498   83 days 17:03:39.825195
# Name: since, Length: 499, dtype: timedelta64[ns]

# %%
for k, v in lastlogin:
    datetime.strptime(v,"%Y-%m-%d %H:%M:%S")
    print (lastlogin)

# %%
print(new_dict)
# Out:
# {datetime.datetime(2020, 6, 23, 15, 22, 27): '2020-06-23 15:22:27', datetime.datetime(2020, 6, 11, 21, 37, 37): '2020-06-11 21:37:37', datetime.datetime(2020, 5, 30, 14, 18, 6): '2020-05-30 14:18:06', datetime.datetime(2020, 5, 21, 5, 36, 45): '2020-05-21 05:36:45', datetime.datetime(2020, 7, 2, 15, 11): '2020-07-02 15:11:00', datetime.datetime(2020, 6, 9, 21, 1, 3): '2020-06-09 21:01:03', datetime.datetime(2020, 5, 20, 23, 25, 15): '2020-05-20 23:25:15', datetime.datetime(2020, 5, 14, 12, 24, 52): '2020-05-14 12:24:52', datetime.datetime(2020, 6, 16, 13, 51, 16): '2020-06-16 13:51:16', datetime.datetime(2020, 6, 14, 4, 37, 53): '2020-06-14 04:37:53', datetime.datetime(2020, 5, 30, 13, 0, 56): '2020-05-30 13:00:56', datetime.datetime(2020, 6, 6, 16, 26, 55): '2020-06-06 16:26:55', datetime.datetime(2020, 6, 9, 20, 49, 34): '2020-06-09 20:49:34', datetime.datetime(2020, 6, 18, 4, 6, 15): '2020-06-18 04:06:15', datetime.datetime(2020, 5, 11, 2, 29, 28): '2020-05-11 02:29:28', datetime.
# ...

# %%
now = datetime.now()
csv_dic=[]
csvFile = csv.reader(open('/home/pimpwhippa/Documents/Works/tornado/last_login.csv', encoding ='us-ascii'))
for col in csvFile:
    csv_dic.append(col[0])
    csv_dic.append(now)
